# %%
print("Model for Prediction of Doctor's fees")
# Out:
# Model for Prediction of Doctor's fees

# %%
import pandas as pd
import math
from sklearn.model_selection import train_test_split
print("Packages imported")
# Out:
# Packages imported

# %%
DataCols = ['Qualification','Experience','Rating','Place','Profile','Miscellaneous_Info']
DocData = pd.read_csv('DocTest.csv',names=DataCols)
DocData = DocData[1:]
DocData.dropna()
Tdata = DocData['Profile']
Qclasses = ['MD','MBBS','BHMS','BAMS','BDS','MDS','Get inspired by remarkable stories of people like you','LCEH','GCEH','BSAM','DDVL','DDV','DNB','G.A.M.S','DLO','M.D.','Diploma in Dermatology','PhD']
Plclasses = ['Ernakulam','Bangalore','Chennai','Hyderabad','Coimbatore','Delhi','Mumbai','Thiruvananthapuram']
Prclasses = ['Homeopath','Dentist','Ayurveda','ENT Specialist','Dermatologists','General Medicine']
print(DocData)
# Out:
#                                           Qualification           Experience  \
# 1                                                  MBBS  35 years experience
# 2            MBBS, Diploma in Otorhinolaryngology (DLO)  31 years experience
# 3                                            MBBS, DDVL  40 years experience
# 4                                                  BAMS   0 years experience
# 5       BDS, MDS - Conservative Dentistry & Endodontics  16 years experience
# 6                                              BDS, MDS  14 years experience
# 7            MBBS, Diploma in Otorhinolaryngology (DLO)  23 years experience
# 8                                BDS, MDS - Pedodontics   9 years experience
# 9     MD - Ayurveda Medicine, BAMS, Yoga Teachers Tr...  11 years experience
# 10                                                 BHMS  44 years experience
# 11                                                  BDS   4 years experience
# 12                              MBBS, FCD - Diabetology  34 years experience
# 13                                            MBBS, DDV  11 years experience
# 14                               MBBS, MD - Dermatology  13 years experience
# 15                                             MS - ENT   4 years experience
# 16                                                  BDS   4 years experience
# 17                               MBBS, MD - Dermatology  16 years experience
# 18    MBBS, Diploma in Otorhinolaryngology (DLO), MS...  28 years experience
# 19      BDS, MDS - Conservative Dentistry & Endodontics   6 years experience
# 20                               MBBS, MD - Dermatology  32 years experience
# 21    BHMS, Diploma in Naturopathy & Yogic Science (...  11 years experience
# 22                                                  BDS   3 years experience
# 23                               MBBS, MD - Dermatology   8 years experience
# 24     MBBS, PG Diploma In Clinical Cosmetology (PGDCC)  13 years experience
# 25                                                 MBBS  43 years experience
# 26           MBBS, Diploma in Otorhinolaryngology (DLO)  27 years experience
# 27                              BDS, MDS - Periodontics  22 years experience
# 28                             BDS, MDS- Oral Pathology   8 years experience
# 29                          MBBS, MD - General Medicine  25 years experience
# 30                                       MS - ENT, MBBS   4 years experience
# ...                                                 ...                  ...
# 1958  MD - Acupuncture, PG Diploma In Clinical Cosme...   8 years experience
# 1959  MBBS, MS - ENT, Diploma in Otorhinolaryngology...  40 years experience
# 1960                                MBBS, MD - Medicine  43 years experience
# 1961                            BDS, MDS - Orthodontics  29 years experience
# 1962                                               BHMS   2 years experience
# 1963                                        MBBS, PGDHA  12 years experience
# 1964                                               BHMS   3 years experience
# 1965  BDS, MDS - Prosthodontist And Crown Bridge, Ce...   8 years experience
# 1966                                    MBBS, MRCOG(UK)  35 years experience
# 1967  MD - Medicine, Post Graduate Diploma in Diabet...  24 years experience
# 1958                   100% 12 Feedback KPHB, Hyderabad   NaN
# 1959            53% 12 Feedback Millers Road, Bangalore   NaN
# 1960  Viral Fever Treatment Dengue Fever Treatment T...   NaN
# 1961  Dental Implant Fixing Invisible/Clear Braces C...   NaN
# 1962             3 Feedback Malleswaram, Bangalore ₹500   NaN
# 1963                     100% 23 Feedback Rohini, Delhi   NaN
# 1964                                                NaN   NaN
# 1965                                                NaN   NaN
# 1966                    88% 5 Feedback Choolai, Chennai   NaN
# 1967                                                NaN   NaN
# 1968  Gum Disease Treatment/ Surgery Dental Implant ...   NaN
# 1969             96% 12 Feedback Indiranagar, Bangalore   NaN
# 1970                                                NaN   NaN
# 1971                                                NaN   NaN
# 1972  Endoscopic DCR Sleep related disorders such as...   NaN
# 1973              93% 36 Feedback Moti Nagar, Hyderabad   NaN
# 1974  Skin Allergy Treatment Skin Allergies Dermabra...   NaN
# 1975                                                NaN   NaN
# 1976  foot and ankle problems 1 Feedback Panchsheel ...   NaN
# 1977                 84% 20 Feedback Miyapur, Hyderabad   NaN
# 1978   Panchsheel Park, Delhi ₹1,000 Available Tomorrow   NaN
# 1979           Prabhadevi, Mumbai ₹1,000 Visits On-Call   NaN
# 1980  General Dentistry Dental Fillings RCT - Single...   NaN
# 1981                98% 240 Feedback Velachery, Chennai   NaN
# 1982                                                NaN   NaN
# 1983                                                NaN   NaN
# 1984                                                NaN   NaN
# 1985                                                NaN   NaN
# 1986  RCT - Root Canal Treatment Root Canal Treatmen...   NaN
# 1987              1 Feedback Pallikaranai, Chennai ₹500   NaN
#
# [1987 rows x 7 columns]

# %%
# Molding the dataset
QUALS = []
Tdata = DocData['Qualification'].values
Tdata = list(Tdata)

for sample in Tdata:
    Include = []
    for qual in Qclasses:
        if qual in sample:
            Include.append(qual)
    
    NewText = ""
    for I in Include:
        NewText = NewText + I + ","
    
    NewText = NewText[:-1]
    QUALS.append(NewText)

QUALS_F = []
for row in QUALS:
    if row=='':
        QUALS_F.append('MS')
    else:
        QUALS_F.append(row)

# QUALS_F contains the FInal Qualifications to be appended in new dataframe

# %%
DocPlaces = []
Tdata = DocData['Place'].values
Tdata = list(Tdata)

for sample in Tdata:
    if sample!=sample:
        DocPlaces.append('Unknown')
    else:
        f=0
        for place in Plclasses:
            if place in sample:
                DocPlaces.append(place)
                f=1
                break
        
        if f==0:
            DocPlaces.append('Unknown')
            
            
#DocPlaces contains Places of Doctors to be appended

# %%
DocProfiles = []
Tdata = DocData['Profile'].values
Tdata = list(Tdata)
'''
for sample in Tdata:
    if sample!=sample:
        DocProfiles.append('Unknown')
    else:
        f=0
        for profile in Prclasses:
            if profile in sample:
                DocProfiles.append(profile)
                f=1
                break
        
        if f==0:
            DocProfiles.append('Unknown')
'''
DocProfiles = Tdata
#Doc Profiles are finalized Profiles

# %%
Ttdata=DocData['Fees'].values
print(Ttdata)
Fdata = []
for i in Ttdata:
    i = int(i)
    Fdata.append(i)
#Now, we have integers in Fdata list as our Fees
# Out:
# [nan nan nan ... nan nan nan]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-708d1113c0dd> in <module>()
#       3 Fdata = []
#       4 for i in Ttdata:
# ----> 5     i = int(i)
#       6     Fdata.append(i)
#       7 #Now, we have integers in Fdata list as our Fees
#
# ValueError: cannot convert float NaN to integer

# %%
Tdata = DocData['Rating'].values
Tdata = list(Tdata)
RatData = []

for sample in Tdata:
    if sample!=sample:
        RatData.append(0)
    else:
        sample  = sample[:-1]
        sample = int(sample)
        RatData.append(sample)

#RatData contains FInal Ratings to be appended

# %%
Tdata = DocData['Experience'].values
Tdata = list(Tdata)
ExpData = []

for sample in Tdata:
    sample = sample[:-17]
    temp = int(sample)
    ExpData.append(temp)

    # ExpData stores Exps to be appended

# %%
#Now, Creating a new DataFrame
NewDocData = []
DataCols = ['Qualification','Experience','Rating','Place','Profile','Fees']
for i in range(len(Tdata)):
    temp = []
    temp.append(QUALS_F[i])
    temp.append(ExpData[i])
    temp.append(RatData[i])
    temp.append(DocPlaces[i])
    temp.append(DocProfiles[i])
    temp.append(Fdata[i])
    NewDocData.append(temp)


myFrame = pd.DataFrame(NewDocData,columns=DataCols)
myFrame.to_csv('Mtrain.csv')
print(myFrame)
# Out:
#                     Qualification  Experience  Rating               Place  \
# 0                         MD,BHMS          24     100           Ernakulam
# 1                         MD,BAMS          12      98           Bangalore
# 2                            MBBS           9       0           Bangalore
# 3                            BAMS          12       0           Bangalore
# 4                            BAMS          20     100             Chennai
# 5                            BAMS           8       0             Chennai
# 6                            BHMS          42       0               Delhi
# 7                             BDS          10      99           Bangalore
# 8                         MD,MBBS          14       0           Hyderabad
# 9                             BDS          23       0           Ernakulam
# 10                       MBBS,DNB           5       0             Chennai
# 11                           BAMS           7       0           Hyderabad
# 12                     MD,BDS,MDS           9      98          Coimbatore
# 13                     MD,BDS,MDS          21       0           Hyderabad
# 14                   MBBS,DNB,DLO          12       0               Delhi
# 15                        MD,MBBS          10       0           Hyderabad
# 16                       MBBS,DLO          24       0             Chennai
# 17                           MBBS           5       0             Chennai
# 18                           MBBS          19      79           Hyderabad
# 19                           MBBS          19     100           Bangalore
# 20                 MD,BDS,MDS,DNB          21     100          Coimbatore
# 21                       MBBS,DNB          14       0               Delhi
# 22                           MBBS          41       0              Mumbai
# 23                           MBBS          31       0           Ernakulam
# 24                  MBBS,DDVL,DDV          23       0              Mumbai
# 25                            BDS           5       0  Thiruvananthapuram
# 26                           MBBS          25     100           Bangalore
# 27                        MD,MBBS          12      95           Hyderabad
# 28                     MD,BDS,MDS          16       0          Coimbatore
# 29    MBBS,Diploma in Dermatology          15      97               Delhi
# ...                           ...         ...     ...                 ...
# 5929                         MBBS          13      99           Bangalore
# 5930                          BDS           9       0          Coimbatore
# 5931                      MD,BHMS          21      96           Bangalore
# 5932                         BHMS          19       0              Mumbai
# 5933                   MD,BDS,MDS          12      99           Bangalore
# 5934                      MD,LCEH          34     100              Mumbai
# 5935                         BHMS          19      96           Bangalore
# 5936                         MBBS          36       0           Bangalore
# 5937                      MD,BHMS           7       0              Mumbai
# 5938                      MD,MBBS          40      80              Mumbai
# 5939                         BHMS          30       0               Delhi
# 5940                      MD,MBBS          51      90           Bangalore
# 5941                          BDS           3      95           Bangalore
# 5942                           MS           2       0             Chennai
# 5943                          BDS           4       0             Chennai
# 5944                          BDS          12      99               Delhi
# 5945                         BHMS           6       0           Bangalore
# 5946                         BAMS          15       0              Mumbai
# 5947                         BHMS           8       0              Mumbai
# 5948                      MD,MBBS           4     100           Bangalore
# 5949                          BDS           4       0           Bangalore
# 5950                         MBBS          47       0              Mumbai
# 5951                           MD          35      92           Bangalore
# 5952                         BHMS          31       0               Delhi
# 5953                           MD          10       0               Delhi
# 5954                         MBBS          19      98           Bangalore
# 5955                         MBBS          33       0             Chennai
# 5956                         MBBS          41      97               Delhi
# 5957                      MD,MBBS          15      90              Mumbai
# 5958                   MD,BDS,MDS          17     100               Delhi
#
#       Profile  Fees
# 0     Unknown   100
# 1     Unknown   350
# 2     Unknown   300
# 3     Unknown   250
# 4     Unknown   250
# 5     Unknown   100
# 6     Unknown   200
# 7     Unknown   200
# 8     Unknown   100
# 9     Unknown   100
# 10    Unknown   700
# 11    Unknown   100
# 12    Unknown   200
# 13    Unknown   350
# 14    Unknown   500
# 15    Unknown   200
# 16    Unknown   100
# 17    Unknown   300
# 18    Unknown   400
# 19    Unknown   150
# 20    Unknown   100
# 21    Unknown   500
# 22    Unknown   200
# 23    Unknown   100
# 24    Unknown   100
# 25    Unknown   100
# 26    Unknown   500
# 27    Unknown   250
# 28    Unknown   100
# 29    Unknown   500
# ...       ...   ...
# 5929  Unknown   300
# 5930  Unknown   100
# 5931  Unknown   500
# 5932  Unknown   100
# 5933  Unknown   300
# 5934  Unknown   100
# 5935  Unknown   400
# 5936  Unknown   300
# 5937  Unknown   400
# 5938  Unknown   800
# 5939  Unknown   300
# 5940  Unknown   450
# 5941  Dentist   300
# 5942  Unknown   200
# 5943  Unknown   150
# 5944  Dentist   300
# 5945  Unknown   100
# 5946  Unknown   100
# 5947  Unknown   400
# 5948  Unknown   350
# 5949  Unknown   200
# 5950  Unknown   100
# 5951  Unknown   100
# 5952  Unknown   300
# 5953  Unknown   300
# 5954  Unknown   300
# 5955  Unknown   100
# 5956  Unknown   600
# 5957  Unknown   100
# 5958  Unknown   200
#
# [5959 rows x 6 columns]

# %%
from sklearn.linear_model import LinearRegression  
from sklearn import metrics 
from sklearn.preprocessing import PolynomialFeatures
from keras.models import Sequential
from keras.layers import Flatten,Dense
DataCols = ['Index','Qualification','Experience','Rating','Place','Profile','Fees']
DocData = pd.read_csv('Mtrain.csv',names=DataCols)
X = DocData.iloc[:,1:6].values
X = X[1:]
Y = DocData.iloc[:,-1].values
Y = Y[1:]
Qclasses = ['MD','MBBS','BHMS','BAMS','BDS','MDS','Get inspired by remarkable stories of people like you','LCEH','GCEH','BSAM','DDVL','DDV','DNB','G.A.M.S','DLO','M.D.','Diploma in Dermatology','PhD','MS']
Qweights = [16,15,5,6,7,14,1,8,9,4,10,11,12,2,13,16,3,17,3]
Plclasses = ['Ernakulam','Bangalore','Chennai','Hyderabad','Coimbatore','Delhi','Mumbai','Thiruvananthapuram','Unknown']
Prclasses = ['Homeopath','Dentist','Ayurveda','ENT Specialist','Dermatologists','General Medicine','Unknown']
Plweights = [2,6,3,4,7,8,9,5,1]
Prweights = [7,6,5,4,3,2,1]
Qdict = dict(zip(Qclasses,Qweights))
Pldict = dict(zip(Plclasses,Plweights))
Prdict = dict(zip(Prclasses,Prweights))
for i in range(len(X)):
    split = X[i][0].split(',')
    X[i][0] = 0
    for j in split:
        X[i][0]+=Qdict[j]
    X[i][1] = int(X[i][1])
    X[i][2] = int(X[i][2])
    X[i][3] = Pldict[X[i][3]]
    X[i][4] = Prdict[X[i][4]]
    Y[i] = int(Y[i])

Xtrain,Xtest,Ytrain,Ytest = train_test_split(X,Y,test_size=0.2,random_state=0)
print(Xtrain[:5])
print(Ytrain[:5])
# Out:
# [[21 21 0 4 1]
#  [28 34 92 6 1]
#  [6 4 0 6 1]
#  [15 28 100 3 1]
#  [7 5 100 4 1]]
# [250 380 200 300 200]

# %%
from sklearn.preprocessing import Normalizer
from keras.models import Sequential
from keras.layers import Flatten,Dense
model = Sequential()
model.add(Dense(64, input_dim=5, kernel_initializer='normal', activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(1, activation='linear'))
model.compile(loss='mse', optimizer='adam', metrics=['accuracy'])
model.fit(Xtrain, Ytrain, epochs=50, batch_size=20,  verbose=1, validation_split=0.1)
# Out:
# Train on 4290 samples, validate on 477 samples
# Epoch 1/50
# 4290/4290 [==============================] - 2s 468us/step - loss: 50100.1114 - acc: 0.0016 - val_loss: 35971.6994 - val_acc: 0.0021
# Epoch 2/50
# 4290/4290 [==============================] - 1s 192us/step - loss: 36811.1543 - acc: 0.0012 - val_loss: 35324.5700 - val_acc: 0.0000e+00
# Epoch 3/50
# 4290/4290 [==============================] - 1s 173us/step - loss: 36399.7709 - acc: 0.0014 - val_loss: 35437.6172 - val_acc: 0.0021
# Epoch 4/50
# 4290/4290 [==============================] - 1s 173us/step - loss: 36505.4863 - acc: 0.0014 - val_loss: 34713.6097 - val_acc: 0.0000e+00
# Epoch 5/50
# 4290/4290 [==============================] - 1s 174us/step - loss: 36137.2406 - acc: 0.0014 - val_loss: 35498.5911 - val_acc: 0.0063
# Epoch 6/50
# 4290/4290 [==============================] - 1s 186us/step - loss: 36163.0117 - acc: 0.0023 - val_loss: 34815.3391 - val_acc: 0.0000e+00
# Epoch 7/50
# 4290/4290 [==============================] - 1s 173us/step - loss: 35865.1297 - acc: 0.0014 - val_loss: 34504.5278 - val_acc: 0.0042
# Epoch 8/50
# 4290/4290 [==============================] - 1s 178us/step - loss: 35710.6139 - acc: 0.0028 - val_loss: 34172.1335 - val_acc: 0.0063
# Epoch 9/50
# 4290/4290 [==============================] - 1s 180us/step - loss: 35477.9659 - acc: 0.0014 - val_loss: 34487.6345 - val_acc: 0.0084
# Epoch 10/50
# 4290/4290 [==============================] - 1s 185us/step - loss: 35278.3578 - acc: 0.0023 - val_loss: 35906.4206 - val_acc: 0.0021
# Epoch 11/50
# 4290/4290 [==============================] - 1s 182us/step - loss: 35438.8949 - acc: 0.0014 - val_loss: 34667.0860 - val_acc: 0.0021
# Epoch 12/50
